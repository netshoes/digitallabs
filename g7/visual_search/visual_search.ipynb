# %% [markdown]
# # Insert your subscription key

# %% [markdown]
# # Dirty Code

# %%
from matplotlib import pyplot as plt
from urllib import request

# %%
file_path = 'exemplocamiseta.jpg'
img = plt.imread(file_path)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
"""Bing Visual Search upload image example"""

# Download and install Python at https://www.python.org/
# Run the following in a command console window
# pip3 install requests

import requests, json


BASE_URI = 'https://api.cognitive.microsoft.com/bing/v7.0/images/visualsearch'
#

HEADERS = {'Ocp-Apim-Subscription-Key': 'f62f5db4efa6496995702b547caa8386'}

imagePath = file_path

file = {'image' : ('myfile', open(file_path, 'rb'))}

response = requests.post(BASE_URI, headers=HEADERS, files=file)
response.raise_for_status()
#result = json.print_json(response.json())

# %%
response.json()
# Out:
# {'_type': 'ImageKnowledge',
#  'image': {'imageInsightsToken': 'bcid_G69c6ff834d3949838e97d3228cd201e7*ccid_w06OSt5H*thid_R.G69c6ff834d3949838e97d3228cd201e7'},
#  'instrumentation': {'_type': 'ResponseInstrumentation',
#   'pageLoadPingUrl': 'https://www.bingapis.com/api/ping/pageload?IG=D84D9EDC6DAE4051AEC514440B56606D&CID=167997E79B4E6E8322709BA89AB36FFD&Type=Event.CPT&DATA=0',
#   'pingUrlBase': 'https://www.bingapis.com/api/ping?IG=D84D9EDC6DAE4051AEC514440B56606D&CID=167997E79B4E6E8322709BA89AB36FFD&ID='},
#  'tags': [{'actions': [{'_type': 'ImageModuleAction',
#      'actionType': 'PagesIncluding',
#      'data': {'value': [{'accentColor': '183676',
#         'contentSize': '96943 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/736x/42/3d/77/423d772ef5e7e820d087ced00645895f.jpg',
#         'contentUrlPingSuffix': 'DevEx,5035.1',
#         'datePublished': '2016-03-17T21:24:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 940,
#         'hostPageDisplayUrl': 'https://br.pinterest.com/explore/casual-chique',
#         'hostPageUrl': 'https://br.pinterest.com/explore/casual-chique/',
#         'hostPageUrlPingSuffix': 'DevEx,5034.1',
#         'imageId': '1D8F7FF40C1F09AC2540554F5352A2A684404E34',
#         'imageInsightsToken': 'ccid_4QYK0TWM*mid_1D8F7FF40C1F09AC2540554F5352A2A684404E34*simid_608019470111998602*thid_OIP.4QYK0TWMV769tsGzoU3n!_QHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '25+ melhores ideias sobre Casual Chique no Pinterest ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.4QYK0TWMV769tsGzoU3n_QHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1D8F7FF40C1F09AC2540554F5352A2A684404E34&simid=608019470111998602',
#         'webSearchUrlPingSuffix': 'DevEx,5033.1',
#         'width': 650},
#        {'accentColor': '183676',
#         'contentSize': '96943 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/originals/42/3d/77/423d772ef5e7e820d087ced00645895f.jpg',
#         'contentUrlPingSuffix': 'DevEx,5041.1',
#         'datePublished': '2017-09-22T22:27:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 940,
#         'hostPageDisplayUrl': 'https://br.pinterest.com/pin/492649936213379',
#         'hostPageUrl': 'https://br.pinterest.com/pin/492649936213379/',
#         'hostPageUrlPingSuffix': 'DevEx,5040.1',
#         'imageId': 'B22EC146B422DADD74ECC3E48B2338A920830E7B',
#         'imageInsightsToken': 'ccid_iV4XLk/g*mid_B22EC146B422DADD74ECC3E48B2338A920830E7B*simid_607991441172530789*thid_OIP.iV4XLk!_gW1lEI3XYYxhg!_gHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Aliste-se já! 30 inspirações para adotar a tendência ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.iV4XLk_gW1lEI3XYYxhg_gHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=B22EC146B422DADD74ECC3E48B2338A920830E7B&simid=607991441172530789',
#         'webSearchUrlPingSuffix': 'DevEx,5039.1',
#         'width': 650},
#        {'accentColor': '183677',
#         'contentSize': '108972 B',
#         'contentUrl': 'https://i.pinimg.com/originals/43/f2/73/43f27365f71999ef05f4ae71a010daeb.jpg',
#         'contentUrlPingSuffix': 'DevEx,5047.1',
#         'datePublished': '2018-06-08T06:36:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1012,
#         'hostPageDisplayUrl': 'https://www.pinterest.fr/pin/509891989047325235',
#         'hostPageUrl': 'https://www.pinterest.fr/pin/509891989047325235/',
#         'hostPageUrlPingSuffix': 'DevEx,5046.1',
#         'imageId': 'F3A00F6D0015E89B2B038E8A58F3C4C1B268C7C3',
#         'imageInsightsToken': 'ccid_Q/JzZfcZ*mid_F3A00F6D0015E89B2B038E8A58F3C4C1B268C7C3*simid_608034661419582600*thid_OIP.Q!_JzZfcZme8F9K5xoBDa6wHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '1001+ looks tendance avec le pantalon en cuir femme ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.Q_JzZfcZme8F9K5xoBDa6wHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=F3A00F6D0015E89B2B038E8A58F3C4C1B268C7C3&simid=608034661419582600',
#         'webSearchUrlPingSuffix': 'DevEx,5045.1',
#         'width': 700},
#        {'accentColor': '153277',
#         'contentSize': '79678 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/originals/34/83/ed/3483ed9e73977fe819fac190675743d0.jpg',
#         'contentUrlPingSuffix': 'DevEx,5053.1',
#         'datePublished': '2018-02-04T22:25:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'https://www.pinterest.es/pin/489977634437106803',
#         'hostPageUrl': 'https://www.pinterest.es/pin/489977634437106803/',
#         'hostPageUrlPingSuffix': 'DevEx,5052.1',
#         'imageId': 'A0FB57B846756353975B6367EC190DA11574C1FE',
#         'imageInsightsToken': 'ccid_/1wqkpPZ*mid_A0FB57B846756353975B6367EC190DA11574C1FE*simid_608022137330339147*thid_OIP.!_1wqkpPZhOSNF2QqSsFGbAHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'look vintage invierno - Buscar con Google | Vintage ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP._1wqkpPZhOSNF2QqSsFGbAHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A0FB57B846756353975B6367EC190DA11574C1FE&simid=608022137330339147',
#         'webSearchUrlPingSuffix': 'DevEx,5051.1',
#         'width': 611},
#        {'accentColor': '183677',
#         'contentSize': '82690 B',
#         'contentUrl': 'http://yourstylearmy.com/wp-content/uploads/2014/09/3219f8e20ec0536a629beecca5912d21.jpg',
#         'contentUrlPingSuffix': 'DevEx,5059.1',
#         'datePublished': '2018-06-11T23:00:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'yourstylearmy.com/sister-brother-style-blog/graphic-tees',
#         'hostPageUrl': 'http://yourstylearmy.com/sister-brother-style-blog/graphic-tees/',
#         'hostPageUrlPingSuffix': 'DevEx,5058.1',
#         'imageId': '679C96458A402FA2F3B91E0BC1ED6BA13B947733',
#         'imageInsightsToken': 'ccid_xPBXQVEi*mid_679C96458A402FA2F3B91E0BC1ED6BA13B947733*simid_608021145180176424*thid_OIP.xPBXQVEiclxCHtN9Q3RxygHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Graphic Tees - Your Style Army',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.xPBXQVEiclxCHtN9Q3RxygHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=679C96458A402FA2F3B91E0BC1ED6BA13B947733&simid=608021145180176424',
#         'webSearchUrlPingSuffix': 'DevEx,5057.1',
#         'width': 611},
#        {'accentColor': '183677',
#         'contentSize': '82599 B',
#         'contentUrl': 'https://i.pinimg.com/originals/c4/f0/57/c4f057415122725c421ed37d437471ca.jpg',
#         'contentUrlPingSuffix': 'DevEx,5065.1',
#         'datePublished': '2018-06-24T10:20:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'https://www.pinterest.ca/pin/390405861422902478',
#         'hostPageUrl': 'https://www.pinterest.ca/pin/390405861422902478/',
#         'hostPageUrlPingSuffix': 'DevEx,5064.1',
#         'imageId': 'A0119E7CC676F0A34BEFF13775829C40D8ADD182',
#         'imageInsightsToken': 'ccid_2WPq1xp9*mid_A0119E7CC676F0A34BEFF13775829C40D8ADD182*simid_608038144644157410*thid_OIP.2WPq1xp9w32x5B-l!_EcOFgHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': "Women's Brown Military Jacket, White and Black Print Crew ...",
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.2WPq1xp9w32x5B-l_EcOFgHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A0119E7CC676F0A34BEFF13775829C40D8ADD182&simid=608038144644157410',
#         'webSearchUrlPingSuffix': 'DevEx,5063.1',
#         'width': 611},
#        {'accentColor': '183677',
#         'contentSize': '82690 B',
#         'contentUrl': 'https://i.pinimg.com/originals/32/19/f8/3219f8e20ec0536a629beecca5912d21.jpg',
#         'contentUrlPingSuffix': 'DevEx,5071.1',
#         'datePublished': '2018-05-27T23:54:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'https://www.pinterest.de/pin/413416440768260619',
#         'hostPageUrl': 'https://www.pinterest.de/pin/413416440768260619/',
#         'hostPageUrlPingSuffix': 'DevEx,5070.1',
#         'imageId': 'CE31EFF3EC495C4E8CD7F375220DCE8A7AF1FB70',
#         'imageInsightsToken': 'ccid_evLOsrll*mid_CE31EFF3EC495C4E8CD7F375220DCE8A7AF1FB70*simid_608006533665653326*thid_OIP.evLOsrllRG!_qOcy2TVfVLAHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 64},
#         'name': 'Leder-Leggins mit Leo Pumps | My Fashion Inspiration ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.evLOsrllRG_qOcy2TVfVLAHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=CE31EFF3EC495C4E8CD7F375220DCE8A7AF1FB70&simid=608006533665653326',
#         'webSearchUrlPingSuffix': 'DevEx,5069.1',
#         'width': 611},
#        {'accentColor': '143377',
#         'contentSize': '79110 B',
#         'contentUrl': 'http://pantalonesdemoda.net/wp-content/uploads/2016/07/Looks-con-jeans-3.jpeg',
#         'contentUrlPingSuffix': 'DevEx,5077.1',
#         'datePublished': '2018-07-22T20:38:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'pantalonesdemoda.net/looks-con-jeans-3',
#         'hostPageUrl': 'http://pantalonesdemoda.net/looks-con-jeans-3/',
#         'hostPageUrlPingSuffix': 'DevEx,5076.1',
#         'imageId': '1FD1C9514870A04B727D272C62C4418CE5784438',
#         'imageInsightsToken': 'ccid_NIPtnnOX*mid_1FD1C9514870A04B727D272C62C4418CE5784438*simid_608047658009299690*thid_OIP.NIPtnnOXf-gZ-sGQZ1dD0AHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 64},
#         'name': 'Pantalones de moda » Looks con jeans 3',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.NIPtnnOXf-gZ-sGQZ1dD0AHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1FD1C9514870A04B727D272C62C4418CE5784438&simid=608047658009299690',
#         'webSearchUrlPingSuffix': 'DevEx,5075.1',
#         'width': 611},
#        {'accentColor': '1C3577',
#         'contentSize': '82865 B',
#         'contentUrl': 'https://cdn1.blovcdn.com/bloglovin/aHR0cHMlM0ElMkYlMkZmYXJtNC5zdGF0aWNmbGlja3IuY29tJTJGMzgwNSUyRjEzNTIyNzgyNTgzX2Y2YzNjNjJkYTFfYi5qcGc=?checksum=0042070c3ad0aee2e3f525afb3ef1995f84810f9&format=j',
#         'contentUrlPingSuffix': 'DevEx,5083.1',
#         'datePublished': '2018-05-26T05:54:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 960,
#         'hostPageDisplayUrl': 'bloglovin.com/blog/post/8736761/2581663787?link...',
#         'hostPageUrl': 'http://bloglovin.com/blog/post/8736761/2581663787?link=ahr0ccuzqsuyriuyrnnlyw1zzm9yywrlc2lyzs5jb20lmkzwyxjlbnrhbc1hzhzpc29yesuyriuzrnv0bv9zb3vyy2ulm0ryc3mlmjz1dg1fbwvkaxvtjtnecnnzjti2dxrtx2nhbxbhawdujtnecgfyzw50ywwtywr2axnvcnk=',
#         'hostPageUrlPingSuffix': 'DevEx,5082.1',
#         'imageId': '1D381AF5AE85105493D3E1F5AECC5618D5FAE390',
#         'imageInsightsToken': 'ccid_e2dXE75/*mid_1D381AF5AE85105493D3E1F5AECC5618D5FAE390*simid_607991767577660050*thid_OIP.e2dXE75!_lmTz1eOP0h3mhwHaLH',
#         'insightsMetadata': {'availableSizesCount': 5,
#          'pagesIncludingCount': 8},
#         'name': 'PARENTAL ADVISORY | Seams for a desire | Bloglovin’',
#         'thumbnail': {'height': 711, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.e2dXE75_lmTz1eOP0h3mhwHaLH&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=1D381AF5AE85105493D3E1F5AECC5618D5FAE390&simid=607991767577660050',
#         'webSearchUrlPingSuffix': 'DevEx,5081.1',
#         'width': 640},
#        {'accentColor': '1A3775',
#         'contentSize': '69733 B',
#         'contentUrl': 'https://i.pinimg.com/originals/b3/0d/8d/b30d8d8c266ab8a9be6b39ac8b40b481.jpg',
#         'contentUrlPingSuffix': 'DevEx,5089.1',
#         'datePublished': '2018-06-17T16:34:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 795,
#         'hostPageDisplayUrl': 'https://www.pinterest.com.mx/pin/322359285808962296',
#         'hostPageUrl': 'https://www.pinterest.com.mx/pin/322359285808962296/',
#         'hostPageUrlPingSuffix': 'DevEx,5088.1',
#         'imageId': 'D684D780A50030DD2225A2B1074AA070F4CA9907',
#         'imageInsightsToken': 'ccid_X1T5JJXU*mid_D684D780A50030DD2225A2B1074AA070F4CA9907*simid_608045347281372515*thid_OIP.X1T5JJXUa9XcgChdYZPhRAHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'outfits color marron moda otoño 2014 | outfits | Pinterest ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.X1T5JJXUa9XcgChdYZPhRAHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=D684D780A50030DD2225A2B1074AA070F4CA9907&simid=608045347281372515',
#         'webSearchUrlPingSuffix': 'DevEx,5087.1',
#         'width': 550},
#        {'accentColor': '123075',
#         'contentSize': '54257 B',
#         'contentUrl': 'http://img.masi-maro.com/imgdet_8788_273457_imgdet_org.jpg',
#         'contentUrlPingSuffix': 'DevEx,5095.1',
#         'datePublished': '2015-07-20T08:29:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 686,
#         'hostPageDisplayUrl': 'masi-maro.com/det/8788',
#         'hostPageUrl': 'http://masi-maro.com/det/8788',
#         'hostPageUrlPingSuffix': 'DevEx,5094.1',
#         'imageId': 'B1528D6DF715F40EA2EB7773E150D7BCF0DFE16E',
#         'imageInsightsToken': 'ccid_kRp9BR/F*mid_B1528D6DF715F40EA2EB7773E150D7BCF0DFE16E*simid_607996217201918493*thid_OIP.kRp9BR!_FOI2EQ!_fCiFNbcgHaKK',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '新作あり！2015年秋冬はアニマル柄を取り入れたコーデで大人っぽく♡｜マシマロ',
#         'thumbnail': {'height': 650, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.kRp9BR_FOI2EQ_fCiFNbcgHaKK&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=B1528D6DF715F40EA2EB7773E150D7BCF0DFE16E&simid=607996217201918493',
#         'webSearchUrlPingSuffix': 'DevEx,5093.1',
#         'width': 500},
#        {'accentColor': '1A3776',
#         'contentSize': '81347 B',
#         'contentUrl': 'https://www.aquimoda.com/wp-content/uploads/2014/09/outfits-color-marron-4.jpg',
#         'contentUrlPingSuffix': 'DevEx,5101.1',
#         'datePublished': '2018-06-22T22:11:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 795,
#         'hostPageDisplayUrl': 'https://www.aquimoda.com/las-mejores-combinaciones-de-outfits-con...',
#         'hostPageUrl': 'https://www.aquimoda.com/las-mejores-combinaciones-de-outfits-con-prendas-color-marron-para-otono/',
#         'hostPageUrlPingSuffix': 'DevEx,5100.1',
#         'imageId': '46848BB53DF84EED7D95A891508F731C7690FA4B',
#         'imageInsightsToken': 'ccid_sw2NjCZq*mid_46848BB53DF84EED7D95A891508F731C7690FA4B*simid_607988026688536947*thid_OIP.sw2NjCZquKm-azmsi0C0gQHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Las mejores combinaciones de Outfits con prendas color ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.sw2NjCZquKm-azmsi0C0gQHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=46848BB53DF84EED7D95A891508F731C7690FA4B&simid=607988026688536947',
#         'webSearchUrlPingSuffix': 'DevEx,5099.1',
#         'width': 550},
#        {'accentColor': '183676',
#         'contentSize': '151597 B',
#         'contentUrl': 'http://www.allteenstalk.com/wp-content/uploads/2015/12/cute-edgy-outfits0281.jpg',
#         'contentUrlPingSuffix': 'DevEx,5107.1',
#         'datePublished': '2018-07-16T22:54:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 868,
#         'hostPageDisplayUrl': 'https://www.allteenstalk.com/edgy-outfits',
#         'hostPageUrl': 'https://www.allteenstalk.com/edgy-outfits/',
#         'hostPageUrlPingSuffix': 'DevEx,5106.1',
#         'imageId': '9A906AB5937B386C92EFE6C448EA2C178BDDCE04',
#         'imageInsightsToken': 'ccid_oUsDtCZX*mid_9A906AB5937B386C92EFE6C448EA2C178BDDCE04*simid_608028901845893223*thid_OIP.oUsDtCZXOp0zW7xqmfP7hwHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '88 Cute Edgy Outfits For Girls',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.oUsDtCZXOp0zW7xqmfP7hwHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=9A906AB5937B386C92EFE6C448EA2C178BDDCE04&simid=608028901845893223',
#         'webSearchUrlPingSuffix': 'DevEx,5105.1',
#         'width': 600},
#        {'accentColor': '183677',
#         'contentSize': '374826 B',
#         'contentUrl': 'https://archzine.fr/wp-content/uploads/2017/02/t-shirt-imprim%C3%A9-veste-kaki-slim-cuir-escarpins-%C3%A0-talons.jpg',
#         'contentUrlPingSuffix': 'DevEx,5113.1',
#         'datePublished': '2018-05-11T14:23:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1012,
#         'hostPageDisplayUrl': 'https://archzine.fr/mode-et-beaute/mode-femme/comment-porter-le...',
#         'hostPageUrl': 'https://archzine.fr/mode-et-beaute/mode-femme/comment-porter-le-pantalon-en-cuir-femme/',
#         'hostPageUrlPingSuffix': 'DevEx,5112.1',
#         'imageId': 'E16E4547EA04B099222EB49055547420C3357F7D',
#         'imageInsightsToken': 'ccid_naFvcpf4*mid_E16E4547EA04B099222EB49055547420C3357F7D*simid_608019328372576089*thid_OIP.naFvcpf4gUG3MqUGSAXEcwHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '1001+ looks tendance avec le pantalon en cuir femme',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.naFvcpf4gUG3MqUGSAXEcwHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=E16E4547EA04B099222EB49055547420C3357F7D&simid=608019328372576089',
#         'webSearchUrlPingSuffix': 'DevEx,5111.1',
#         'width': 700},
#        {'accentColor': '183876',
#         'contentSize': '81223 B',
#         'contentUrl': 'https://i.pinimg.com/736x/c7/46/25/c74625a79a194f4a3cddc47b576147e9--black-skinnies-black-pants.jpg',
#         'contentUrlPingSuffix': 'DevEx,5119.1',
#         'datePublished': '2017-10-25T22:31:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'https://www.pinterest.com/andrelinoge/new',
#         'hostPageUrl': 'https://www.pinterest.com/andrelinoge/new/',
#         'hostPageUrlPingSuffix': 'DevEx,5118.1',
#         'imageId': 'CD8F529C8FF485110574CDDC1551042861E04B9A',
#         'imageInsightsToken': 'ccid_VedNWMTg*mid_CD8F529C8FF485110574CDDC1551042861E04B9A*simid_608012688427978143*thid_OIP.VedNWMTg2ehO3-sBg7Tr1QHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '58 best New images on Pinterest | Nylons, Pantyhose ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.VedNWMTg2ehO3-sBg7Tr1QHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=CD8F529C8FF485110574CDDC1551042861E04B9A&simid=608012688427978143',
#         'webSearchUrlPingSuffix': 'DevEx,5117.1',
#         'width': 611},
#        {'accentColor': '1A3578',
#         'contentSize': '213353 B',
#         'contentUrl': 'https://farm4.staticflickr.com/3805/13522782583_f6c3c62da1_b.jpg',
#         'contentUrlPingSuffix': 'DevEx,5125.1',
#         'datePublished': '2018-07-11T07:58:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1024,
#         'hostPageDisplayUrl': 'seamsforadesire.com/parental-advisory',
#         'hostPageUrl': 'http://seamsforadesire.com/parental-advisory/',
#         'hostPageUrlPingSuffix': 'DevEx,5124.1',
#         'imageId': '0B28485A51E90E0AC2406D5A8D5BA31C480EC5B8',
#         'imageInsightsToken': 'ccid_s8dy3nP6*mid_0B28485A51E90E0AC2406D5A8D5BA31C480EC5B8*simid_608051209936373421*thid_OIP.s8dy3nP6quad6SwkyH0jyAHaLG',
#         'insightsMetadata': {'availableSizesCount': 5,
#          'pagesIncludingCount': 8},
#         'name': 'PARENTAL ADVISORY | seams for a desire',
#         'thumbnail': {'height': 710, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.s8dy3nP6quad6SwkyH0jyAHaLG&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=0B28485A51E90E0AC2406D5A8D5BA31C480EC5B8&simid=608051209936373421',
#         'webSearchUrlPingSuffix': 'DevEx,5123.1',
#         'width': 683},
#        {'accentColor': '183677',
#         'contentSize': '82599 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/736x/c4/f0/57/c4f057415122725c421ed37d437471ca.jpg',
#         'contentUrlPingSuffix': 'DevEx,5131.1',
#         'datePublished': '2016-01-21T13:44:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'https://fr.pinterest.com/pin/508625351645648440',
#         'hostPageUrl': 'https://fr.pinterest.com/pin/508625351645648440/',
#         'hostPageUrlPingSuffix': 'DevEx,5130.1',
#         'imageId': 'A06CB55C70BF7C4203D0DA3D4C3B0CB58F445791',
#         'imageInsightsToken': 'ccid_TMuRJaea*mid_A06CB55C70BF7C4203D0DA3D4C3B0CB58F445791*simid_608036439534342002*thid_OIP.TMuRJaeahp0ATY4Hzr5azgHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Acheter la tenue sur Lookastic: https://lookastic.fr/mode ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.TMuRJaeahp0ATY4Hzr5azgHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=A06CB55C70BF7C4203D0DA3D4C3B0CB58F445791&simid=608036439534342002',
#         'webSearchUrlPingSuffix': 'DevEx,5129.1',
#         'width': 611},
#        {'accentColor': '193676',
#         'contentSize': '140512 B',
#         'contentUrl': 'http://www.ofertefashion.com/wp-content/uploads/2015/02/idei-imbracaminte-de-primavara-15.jpg',
#         'contentUrlPingSuffix': 'DevEx,5137.1',
#         'datePublished': '2015-02-24T20:14:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 868,
#         'hostPageDisplayUrl': 'www.ofertefashion.com/lifestyle/pentru-ele-cum-sa-ma-imbrac-in...',
#         'hostPageUrl': 'http://www.ofertefashion.com/lifestyle/pentru-ele-cum-sa-ma-imbrac-in-primavara-2015-24-fotografii.html',
#         'hostPageUrlPingSuffix': 'DevEx,5136.1',
#         'imageId': '73BF4E8AEB8C029E5189B874D86BF99314BF5B07',
#         'imageInsightsToken': 'ccid_pBAqWbmX*mid_73BF4E8AEB8C029E5189B874D86BF99314BF5B07*simid_607991084682577330*thid_OIP.pBAqWbmXd!_hxbFO6HfIgfwHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 64},
#         'name': 'Pentru ELE: Cum sa ma imbrac in primavara 2015? (24 FOTO)',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.pBAqWbmXd_hxbFO6HfIgfwHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=73BF4E8AEB8C029E5189B874D86BF99314BF5B07&simid=607991084682577330',
#         'webSearchUrlPingSuffix': 'DevEx,5135.1',
#         'width': 600},
#        {'accentColor': '163378',
#         'contentSize': '49446 B',
#         'contentUrl': 'http://m1.paperblog.com/i/263/2635679/outfits-invierno-L-xtKqmc.jpeg',
#         'contentUrlPingSuffix': 'DevEx,5143.1',
#         'datePublished': '2014-06-21T05:54:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 665,
#         'hostPageDisplayUrl': 'es.paperblog.com/outfits-de-invierno-2635679',
#         'hostPageUrl': 'http://es.paperblog.com/outfits-de-invierno-2635679/',
#         'hostPageUrlPingSuffix': 'DevEx,5142.1',
#         'imageId': 'D4A65E0CA2C7EDD66D0092C201AE2F3CF27A33AD',
#         'imageInsightsToken': 'ccid_JMzocMKU*mid_D4A65E0CA2C7EDD66D0092C201AE2F3CF27A33AD*simid_607999034677594845*thid_OIP.JMzocMKU1jH3xk4GGiNY4AHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Outfits de invierno - Paperblog',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.JMzocMKU1jH3xk4GGiNY4AHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=D4A65E0CA2C7EDD66D0092C201AE2F3CF27A33AD&simid=607999034677594845',
#         'webSearchUrlPingSuffix': 'DevEx,5141.1',
#         'width': 460},
#        {'accentColor': '153477',
#         'contentSize': '22605 B',
#         'contentUrl': 'http://reddemoda.com/wp-content/uploads/2015/01/Los-mejores-looks-casuales-para-invierno-6-207x300.jpeg',
#         'contentUrlPingSuffix': 'DevEx,5149.1',
#         'datePublished': '2018-07-05T23:57:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 300,
#         'hostPageDisplayUrl': 'reddemoda.com/los-mejores-looks-casuales-para-invierno',
#         'hostPageUrl': 'http://reddemoda.com/los-mejores-looks-casuales-para-invierno/',
#         'hostPageUrlPingSuffix': 'DevEx,5148.1',
#         'imageId': '06DDF06CA5B06BF1C6BEEDD38482ABF114548AFA',
#         'imageInsightsToken': 'ccid_71oSzAGG*mid_06DDF06CA5B06BF1C6BEEDD38482ABF114548AFA*simid_607987592898742294*thid_OIP.71oSzAGG!_02MUr524fkIlQAAAA',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Los mejores looks casuales para invierno',
#         'thumbnail': {'height': 300, 'width': 207},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.71oSzAGG_02MUr524fkIlQAAAA&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=06DDF06CA5B06BF1C6BEEDD38482ABF114548AFA&simid=607987592898742294',
#         'webSearchUrlPingSuffix': 'DevEx,5147.1',
#         'width': 207},
#        {'accentColor': '1A3875',
#         'contentSize': '79137 B',
#         'contentUrl': 'http://v.3bir.net/imgcache/2015/12/ebdbf009b37c1-1.jpg',
#         'contentUrlPingSuffix': 'DevEx,5155.1',
#         'datePublished': '2018-06-23T19:47:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 632,
#         'hostPageDisplayUrl': 'https://forum.galbdz.com/threads/ازياء-رسمية-وانيقة...',
#         'hostPageUrl': 'https://forum.galbdz.com/threads/%D8%A7%D8%B2%D9%8A%D8%A7%D8%A1-%D8%B1%D8%B3%D9%85%D9%8A%D8%A9-%D9%88%D8%A7%D9%86%D9%8A%D9%82%D8%A9-%D9%84%D9%84%D8%A8%D9%86%D8%A7%D8%AA-2016.60041/',
#         'hostPageUrlPingSuffix': 'DevEx,5154.1',
#         'imageId': '323E9055AC0CF136F9A4C0B540FF0A15A6EF2E4E',
#         'imageInsightsToken': 'ccid_GtWdz+cC*mid_323E9055AC0CF136F9A4C0B540FF0A15A6EF2E4E*simid_608048852026461070*thid_OIP.GtWdz-cCS4OoYE4XyP2U-AHaKt',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 2},
#         'name': 'ازياء رسمية وانيقة للبنات 2016',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.GtWdz-cCS4OoYE4XyP2U-AHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=323E9055AC0CF136F9A4C0B540FF0A15A6EF2E4E&simid=608048852026461070',
#         'webSearchUrlPingSuffix': 'DevEx,5153.1',
#         'width': 437},
#        {'accentColor': '183677',
#         'contentSize': '85756 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/736x/32/19/f8/3219f8e20ec0536a629beecca5912d21--black-skinnies-black-pants.jpg',
#         'contentUrlPingSuffix': 'DevEx,5161.1',
#         'datePublished': '2017-08-10T23:47:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 884,
#         'hostPageDisplayUrl': 'https://www.pinterest.com/explore/black-pants-brown-shoes',
#         'hostPageUrl': 'https://www.pinterest.com/explore/black-pants-brown-shoes/',
#         'hostPageUrlPingSuffix': 'DevEx,5160.1',
#         'imageId': '01F526944608B3C7B7144897E39F49810A279749',
#         'imageInsightsToken': 'ccid_xfsJ8JDA*mid_01F526944608B3C7B7144897E39F49810A279749*simid_608045235618317576*thid_OIP.xfsJ8JDAPSdMaCa4XOjB0QHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '25+ best Black pants brown shoes ideas on Pinterest',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.xfsJ8JDAPSdMaCa4XOjB0QHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=01F526944608B3C7B7144897E39F49810A279749&simid=608045235618317576',
#         'webSearchUrlPingSuffix': 'DevEx,5159.1',
#         'width': 611},
#        {'accentColor': '1A3578',
#         'contentSize': '141391 B',
#         'contentUrl': 'http://picture-cdn.wheretoget.it/5og46c-l.jpg',
#         'contentUrlPingSuffix': 'DevEx,5167.1',
#         'datePublished': '2014-04-06T22:49:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 900,
#         'hostPageDisplayUrl': 'wheretoget.it/look/479435',
#         'hostPageUrl': 'http://wheretoget.it/look/479435',
#         'hostPageUrlPingSuffix': 'DevEx,5166.1',
#         'imageId': '7F83973D0453542EE29E47C44849F8696496AC0C',
#         'imageInsightsToken': 'ccid_gLI+nrHo*mid_7F83973D0453542EE29E47C44849F8696496AC0C*simid_608012636895776475*thid_OIP.gLI-nrHojtZmsznh8Gf-VAHaLH',
#         'insightsMetadata': {'availableSizesCount': 5,
#          'pagesIncludingCount': 7},
#         'name': 'Coat: seams for a desire, t-shirt, jeans, shoes, bag ...',
#         'thumbnail': {'height': 711, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.gLI-nrHojtZmsznh8Gf-VAHaLH&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=7F83973D0453542EE29E47C44849F8696496AC0C&simid=608012636895776475',
#         'webSearchUrlPingSuffix': 'DevEx,5165.1',
#         'width': 600},
#        {'accentColor': '1A3775',
#         'contentSize': '61904 B',
#         'contentUrl': 'http://www.prettydesigns.com/wp-content/uploads/2014/09/Casual-chic-Outfit-Idea-for-Work.jpg',
#         'contentUrlPingSuffix': 'DevEx,5173.1',
#         'datePublished': '2018-05-30T11:11:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 632,
#         'hostPageDisplayUrl': 'https://www.prettydesigns.com/trendy-work-outfit-ideas-early-fall',
#         'hostPageUrl': 'https://www.prettydesigns.com/trendy-work-outfit-ideas-early-fall/',
#         'hostPageUrlPingSuffix': 'DevEx,5172.1',
#         'imageId': 'C1016E931FF12392C8B1B7D5AC75C4F699A07647',
#         'imageInsightsToken': 'ccid_Te/vGYSK*mid_C1016E931FF12392C8B1B7D5AC75C4F699A07647*simid_607991840594724178*thid_OIP.Te!_vGYSKitpjvBd-ntDSigHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 64},
#         'name': 'Trendy Work Outfit Ideas for Early Fall - Pretty Designs',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.Te_vGYSKitpjvBd-ntDSigHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=C1016E931FF12392C8B1B7D5AC75C4F699A07647&simid=607991840594724178',
#         'webSearchUrlPingSuffix': 'DevEx,5171.1',
#         'width': 437},
#        {'accentColor': '203C75',
#         'contentSize': '100348 B',
#         'contentUrl': 'https://farm8.staticflickr.com/7403/16580287715_7b5a0f6026_o.jpg',
#         'contentUrlPingSuffix': 'DevEx,5179.1',
#         'creativeCommons': 'AttributionNonCommercialNoDerivs',
#         'datePublished': '2018-07-15T22:27:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 505,
#         'hostPageDisplayUrl': 'www.luciagallegoblog.com/2015/02/friday-inspiration-zapatos-animal...',
#         'hostPageUrl': 'http://www.luciagallegoblog.com/2015/02/friday-inspiration-zapatos-animal-print.html',
#         'hostPageUrlPingSuffix': 'DevEx,5178.1',
#         'imageId': 'D59FAF6824F74D1CA6B29DBF679551843459ECBD',
#         'imageInsightsToken': 'ccid_e3BoLmEF*mid_D59FAF6824F74D1CA6B29DBF679551843459ECBD*simid_608024731466795140*thid_OIP.e3BoLmEFL0IXrhoAe1B9EAHaFV',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 1},
#         'name': 'lucia gallego blog: Friday Inspiration: Zapatos Animal Print',
#         'thumbnail': {'height': 341, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.e3BoLmEFL0IXrhoAe1B9EAHaFV&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=D59FAF6824F74D1CA6B29DBF679551843459ECBD&simid=608024731466795140',
#         'webSearchUrlPingSuffix': 'DevEx,5177.1',
#         'width': 700},
#        {'accentColor': '344465',
#         'contentSize': '72385 B',
#         'contentUrl': 'https://www.bien.hu/userfiles/cikkek/122526/753x440.jpg',
#         'contentUrlPingSuffix': 'DevEx,5185.1',
#         'datePublished': '2018-04-21T07:33:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 440,
#         'hostPageDisplayUrl': 'https://www.bien.hu/szepseg-es-divat/trendek/igy-viseld-trendin-a...',
#         'hostPageUrl': 'https://www.bien.hu/szepseg-es-divat/trendek/igy-viseld-trendin-a-bornadragot/122526',
#         'hostPageUrlPingSuffix': 'DevEx,5184.1',
#         'imageId': '465708B9B1E85623C874339E35DE390CBB691C7B',
#         'imageInsightsToken': 'ccid_aShl/t4t*mid_465708B9B1E85623C874339E35DE390CBB691C7B*simid_608004704031735970*thid_OIP.aShl!_t4tOD-y0ZjjeYxOkwHaEW',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 1},
#         'name': 'Így viseld trendin a bőrnadrágot - bien.hu - Életem gardróbja',
#         'thumbnail': {'height': 278, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.aShl_t4tOD-y0ZjjeYxOkwHaEW&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=465708B9B1E85623C874339E35DE390CBB691C7B&simid=608004704031735970',
#         'webSearchUrlPingSuffix': 'DevEx,5183.1',
#         'width': 750},
#        {'accentColor': '1A3875',
#         'contentSize': '258074 B',
#         'contentUrl': 'http://outfitideashq.com/wp-content/uploads/2017/01/t-shirt-women-outfit-ideas-10.jpg',
#         'contentUrlPingSuffix': 'DevEx,5191.1',
#         'datePublished': '2018-05-07T16:46:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 882,
#         'hostPageDisplayUrl': 'https://outfitideashq.com/can-basic-t-shirt-right-now',
#         'hostPageUrl': 'https://outfitideashq.com/can-basic-t-shirt-right-now/',
#         'hostPageUrlPingSuffix': 'DevEx,5190.1',
#         'imageId': 'D135F5836C1DFC769178500FD1BE85592FDA8EB0',
#         'imageInsightsToken': 'ccid_w06OSt5H*mid_D135F5836C1DFC769178500FD1BE85592FDA8EB0*simid_608034240515343447*thid_OIP.w06OSt5HQ4hG4ZWFldLhIwHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 64},
#         'name': 'What You Can Do With Your Basic T-Shirt Right Now - Outfit ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.w06OSt5HQ4hG4ZWFldLhIwHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=D135F5836C1DFC769178500FD1BE85592FDA8EB0&simid=608034240515343447',
#         'webSearchUrlPingSuffix': 'DevEx,5189.1',
#         'width': 610},
#        {'accentColor': '183776',
#         'contentSize': '70046 B',
#         'contentUrl': 'http://fashionsy.com/wp-content/uploads/2014/09/fall-2014-1.jpg',
#         'contentUrlPingSuffix': 'DevEx,5197.1',
#         'datePublished': '2018-07-09T05:09:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 632,
#         'hostPageDisplayUrl': 'https://fashionsy.com/fantastic-collection-of-fall-outfits-to...',
#         'hostPageUrl': 'https://fashionsy.com/fantastic-collection-of-fall-outfits-to-update-your-office-attire/',
#         'hostPageUrlPingSuffix': 'DevEx,5196.1',
#         'imageId': '9610C0B208D77CCACDD6FF587932048B53313CC2',
#         'imageInsightsToken': 'ccid_xWSiScEj*mid_9610C0B208D77CCACDD6FF587932048B53313CC2*simid_607990371725150275*thid_OIP.xWSiScEj9jFLLyX50QRFTgAAAA',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': 'Fantastic Collection of Fall Outfits To Update Your Office ...',
#         'thumbnail': {'height': 632, 'width': 437},
#         'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.xWSiScEj9jFLLyX50QRFTgAAAA&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=9610C0B208D77CCACDD6FF587932048B53313CC2&simid=607990371725150275',
#         'webSearchUrlPingSuffix': 'DevEx,5195.1',
#         'width': 437},
#        {'accentColor': '1B3A73',
#         'contentSize': '104695 B',
#         'contentUrl': 'http://www.inspiredluv.com/wp-content/uploads/2016/12/amazing-womens-black-jeans-ideas.jpg',
#         'contentUrlPingSuffix': 'DevEx,5203.1',
#         'datePublished': '2018-06-29T22:17:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1024,
#         'hostPageDisplayUrl': 'www.inspiredluv.com/black-jeans-outfit-ideas-for-women-to-try-in-2017',
#         'hostPageUrl': 'http://www.inspiredluv.com/black-jeans-outfit-ideas-for-women-to-try-in-2017/',
#         'hostPageUrlPingSuffix': 'DevEx,5202.1',
#         'imageId': '62261A0B91DAABF7ECB2DD8137B9EB5466E947A7',
#         'imageInsightsToken': 'ccid_+CBe6U4H*mid_62261A0B91DAABF7ECB2DD8137B9EB5466E947A7*simid_607991655913161455*thid_OIP.-CBe6U4HhlBdbci4b7!_48wHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 64},
#         'name': '25 Black Jeans Outfit Ideas For Women To Try In 2017 ...',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.-CBe6U4HhlBdbci4b7_48wHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=62261A0B91DAABF7ECB2DD8137B9EB5466E947A7&simid=607991655913161455',
#         'webSearchUrlPingSuffix': 'DevEx,5201.1',
#         'width': 708},
#        {'accentColor': '1A3875',
#         'contentSize': '273761 B',
#         'contentUrl': 'http://www.lovethispic.com/uploaded_images/blogs/36-1425580995-22-3.jpg',
#         'contentUrlPingSuffix': 'DevEx,5209.1',
#         'datePublished': '2018-07-11T20:30:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 882,
#         'hostPageDisplayUrl': 'www.lovethispic.com/blog/4039/40-edgy-and-chic-outfits-for-women',
#         'hostPageUrl': 'http://www.lovethispic.com/blog/4039/40-edgy-and-chic-outfits-for-women',
#         'hostPageUrlPingSuffix': 'DevEx,5208.1',
#         'imageId': 'FF483141C404D761BEDAC01639324A52321D829B',
#         'imageInsightsToken': 'ccid_5dyIPQV5*mid_FF483141C404D761BEDAC01639324A52321D829B*simid_608041005093750826*thid_OIP.5dyIPQV5hAPeQgCG22IdggHaKt',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '40 Edgy and Chic Outfits For Women',
#         'thumbnail': {'height': 685, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.5dyIPQV5hAPeQgCG22IdggHaKt&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=FF483141C404D761BEDAC01639324A52321D829B&simid=608041005093750826',
#         'webSearchUrlPingSuffix': 'DevEx,5207.1',
#         'width': 610},
#        {'accentColor': '1B3974',
#         'contentSize': '18453 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/236x/fb/be/e1/fbbee139ad1df58e404c41a94a6bec05.jpg',
#         'contentUrlPingSuffix': 'DevEx,5215.1',
#         'datePublished': '2016-11-02T02:44:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 341,
#         'hostPageDisplayUrl': 'https://www.pinterest.com/tina_tinsel/classycasual-chic-winter-styles',
#         'hostPageUrl': 'https://www.pinterest.com/tina_tinsel/classycasual-chic-winter-styles/',
#         'hostPageUrlPingSuffix': 'DevEx,5214.1',
#         'imageId': '816FE6636ED3A4CC296BB76098A64B41B038055D',
#         'imageInsightsToken': 'ccid_Fhy0xCMz*mid_816FE6636ED3A4CC296BB76098A64B41B038055D*simid_608039609257037652*thid_OIP.Fhy0xCMznosxAscWVKoCeQHaKs',
#         'insightsMetadata': {'availableSizesCount': 14,
#          'pagesIncludingCount': 68},
#         'name': '1000+ images about Classy/casual chic winter styles on ...',
#         'thumbnail': {'height': 684, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.Fhy0xCMznosxAscWVKoCeQHaKs&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=816FE6636ED3A4CC296BB76098A64B41B038055D&simid=608039609257037652',
#         'webSearchUrlPingSuffix': 'DevEx,5213.1',
#         'width': 236},
#        {'accentColor': '1C3576',
#         'contentSize': '91329 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/736x/a0/63/f9/a063f9635c699a4aae695ac7e4123e9c.jpg',
#         'contentUrlPingSuffix': 'DevEx,5221.1',
#         'datePublished': '2016-12-28T20:36:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1024,
#         'hostPageDisplayUrl': 'https://www.pinterest.com/pin/241224123766609275',
#         'hostPageUrl': 'https://www.pinterest.com/pin/241224123766609275/',
#         'hostPageUrlPingSuffix': 'DevEx,5220.1',
#         'imageId': '27AE07EEC5E868F2195E0DA1A0B308FA65EAB3D2',
#         'imageInsightsToken': 'ccid_eg8dP38h*mid_27AE07EEC5E868F2195E0DA1A0B308FA65EAB3D2*simid_607993116203158193*thid_OIP.eg8dP38hEkAIPKyEJiGXrgHaLG',
#         'insightsMetadata': {'availableSizesCount': 5,
#          'pagesIncludingCount': 7},
#         'name': '#OOTD – Page 2 | FashionIndie - The Independent Fashion ...',
#         'thumbnail': {'height': 710, 'width': 474},
#         'thumbnailUrl': 'https://tse4.mm.bing.net/th?id=OIP.eg8dP38hEkAIPKyEJiGXrgHaLG&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=27AE07EEC5E868F2195E0DA1A0B308FA65EAB3D2&simid=607993116203158193',
#         'webSearchUrlPingSuffix': 'DevEx,5219.1',
#         'width': 683}]}},
#     {'actionType': 'MoreSizes'},
#     {'_type': 'ImageModuleAction',
#      'actionType': 'VisualSearch',
#      'data': {'value': [{'accentColor': '5D5B70',
#         'contentSize': '137352 B',
#         'contentUrl': 'http://www.kadinmoda.tv/wp-content/uploads/siyah-yazl%C4%B1k-%C5%9Fort-ve-beyaz-orta-uzun-bluz-alt%C4%B1n-renk-k%C4%B1sa-kolye-ile-yazl%C4%B1k-bayan-k%C4%B1yafet-giyim-kombini-modeli.jpg',
#         'contentUrlPingSuffix': 'DevEx,5228.1',
#         'datePublished': '2015-09-05T03:06:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 942,
#         'hostPageDisplayUrl': 'www.kadinmoda.tv/yazlik-bayan-siyah-ve-beyaz-renk-kiyafet-kombin...',
#         'hostPageUrl': 'http://www.kadinmoda.tv/yazlik-bayan-siyah-ve-beyaz-renk-kiyafet-kombin-modelleri.html/siyah-yazlik-sort-ve-beyaz-orta-uzun-bluz-altin-renk-kisa-kolye-ile-yazlik-bayan-kiyafet-giyim-kombini-modeli',
#         'hostPageUrlPingSuffix': 'DevEx,5227.1',
#         'imageId': '573CCD8F2D26C467536761504B9268432FB27868',
#         'imageInsightsToken': 'ccid_douae5I0*mid_573CCD8F2D26C467536761504B9268432FB27868*simid_608006086986239461*thid_OIP.douae5I0mht4OuZMqTAKPAHaMw',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 1},
#         'name': 'siyah yazlık şort ve beyaz orta uzun bluz altın renk kısa ...',
#         'thumbnail': {'height': 816, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.douae5I0mht4OuZMqTAKPAHaMw&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=573CCD8F2D26C467536761504B9268432FB27868&simid=608006086986239461',
#         'webSearchUrlPingSuffix': 'DevEx,5226.1',
#         'width': 547},
#        {'accentColor': '4E5A69',
#         'contentSize': '46784 B',
#         'contentUrl': 'http://ilarge.lisimg.com/image/7930360/760full-georgia-fowler.jpg',
#         'contentUrlPingSuffix': 'DevEx,5234.1',
#         'datePublished': '2018-03-10T02:03:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1013,
#         'hostPageDisplayUrl': 'listal.com/viewimage/7930360h',
#         'hostPageUrl': 'http://listal.com/viewimage/7930360h',
#         'hostPageUrlPingSuffix': 'DevEx,5233.1',
#         'imageId': '4825C209DECF32A32294960A538A28BC67A33442',
#         'imageInsightsToken': 'ccid_BOUkETlr*mid_4825C209DECF32A32294960A538A28BC67A33442*simid_608033750895431480*thid_OIP.BOUkETlrfLfrYvwFpV86PgHaJ3',
#         'insightsMetadata': {'availableSizesCount': 3,
#          'pagesIncludingCount': 4},
#         'name': 'Picture of Georgia Fowler',
#         'thumbnail': {'height': 631, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.BOUkETlrfLfrYvwFpV86PgHaJ3&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=4825C209DECF32A32294960A538A28BC67A33442&simid=608033750895431480',
#         'webSearchUrlPingSuffix': 'DevEx,5232.1',
#         'width': 760},
#        {'accentColor': '988B33',
#         'contentSize': '57769 B',
#         'contentUrl': 'http://i1142.photobucket.com/albums/n601/seamsforadesire/Julio%202012/IMG_9146.jpg',
#         'contentUrlPingSuffix': 'DevEx,5240.1',
#         'datePublished': '2012-07-02T12:00:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1023,
#         'hostPageDisplayUrl': 'seamsforadesire.com/easy-quick',
#         'hostPageUrl': 'http://seamsforadesire.com/easy-quick/',
#         'hostPageUrlPingSuffix': 'DevEx,5239.1',
#         'imageId': '054185852F1A40F9B23B52B9861415D3FB3C3C1D',
#         'imageInsightsToken': 'ccid_HTJj+IKQ*mid_054185852F1A40F9B23B52B9861415D3FB3C3C1D*simid_608032771644523100*thid_OIP.HTJj-IKQdqzDgf3w!_WJhTgHaLH',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 1},
#         'name': 'Easy & Quick | seams for a desire',
#         'thumbnail': {'height': 711, 'width': 474},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.HTJj-IKQdqzDgf3w_WJhTgHaLH&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=054185852F1A40F9B23B52B9861415D3FB3C3C1D&simid=608032771644523100',
#         'webSearchUrlPingSuffix': 'DevEx,5238.1',
#         'width': 682},
#        {'accentColor': '103089',
#         'contentSize': '73880 B',
#         'contentUrl': 'https://i.pinimg.com/736x/7f/3a/43/7f3a43351b1809857ef8b6497b673129--play-hard-trending-fashion.jpg',
#         'contentUrlPingSuffix': 'DevEx,5246.1',
#         'datePublished': '2018-05-11T12:53:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 709,
#         'hostPageDisplayUrl': 'https://br.pinterest.com/adrianyaraujo/streetstyle-fallwinter',
#         'hostPageUrl': 'https://br.pinterest.com/adrianyaraujo/streetstyle-fallwinter/',
#         'hostPageUrlPingSuffix': 'DevEx,5245.1',
# ...
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=6412CC940337A6E794DF0FF19BDB0F95EA1C17A0&simid=607985952223921657',
#         'webSearchUrlPingSuffix': 'DevEx,5388.1',
#         'width': 736},
#        {'accentColor': '374C5F',
#         'contentSize': '69709 B',
#         'contentUrl': 'http://cdn.newsapi.com.au/image/v1/625ac7257dcf6bab8a156dd744926e59?width=650',
#         'contentUrlPingSuffix': 'DevEx,5396.1',
#         'datePublished': '2018-02-12T14:23:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1000,
#         'hostPageDisplayUrl': 'www.goldcoastbulletin.com.au/news/national/aussie-models-bridget...',
#         'hostPageUrl': 'http://www.goldcoastbulletin.com.au/news/national/aussie-models-bridget-malcolm-chantal-monaghan-and-kelly-gale-audition-for-victorias-secret-show/news-story/49a04eeb535dab6c2cc713c723285d1e',
#         'hostPageUrlPingSuffix': 'DevEx,5395.1',
#         'imageId': 'B80AF3E95F404DE26C6DA58F313326DE18B7231E',
#         'imageInsightsToken': 'ccid_9HxpPgSN*mid_B80AF3E95F404DE26C6DA58F313326DE18B7231E*simid_608044337977492783*thid_OIP.9HxpPgSNGmzqwMXH2nzjKAHaLZ',
#         'insightsMetadata': {'availableSizesCount': 9,
#          'pagesIncludingCount': 24},
#         'name': 'Aussie models Bridget Malcolm, Chantal Monaghan and Kelly ...',
#         'thumbnail': {'height': 729, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.9HxpPgSNGmzqwMXH2nzjKAHaLZ&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=B80AF3E95F404DE26C6DA58F313326DE18B7231E&simid=608044337977492783',
#         'webSearchUrlPingSuffix': 'DevEx,5394.1',
#         'width': 650},
#        {'accentColor': '847A47',
#         'contentSize': '51917 B',
#         'contentUrl': 'http://img.shein.com/images/lookbook/wearing/201551/2222221450236710540071144.jpg',
#         'contentUrlPingSuffix': 'DevEx,5402.1',
#         'datePublished': '2018-01-14T01:07:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 432,
#         'hostPageDisplayUrl': 'fr.shein.com/White-Long-Sleeve-Lace-Dip-Hem-Blouse-p-217012-cat...',
#         'hostPageUrl': 'http://fr.shein.com/White-Long-Sleeve-Lace-Dip-Hem-Blouse-p-217012-cat-1733.html',
#         'hostPageUrlPingSuffix': 'DevEx,5401.1',
#         'imageId': '4B7A152E624D7C43A81A42EE7FE044F8415955D8',
#         'imageInsightsToken': 'ccid_ploPCYcQ*mid_4B7A152E624D7C43A81A42EE7FE044F8415955D8*simid_608044552710852595*thid_OIP.ploPCYcQxIw5CN9t332sXAAAAA',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 1},
#         'name': 'chemisier trapèze dentelle -blanc -French SheIn(Sheinside)',
#         'thumbnail': {'height': 432, 'width': 304},
#         'thumbnailUrl': 'https://tse3.mm.bing.net/th?id=OIP.ploPCYcQxIw5CN9t332sXAAAAA&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=4B7A152E624D7C43A81A42EE7FE044F8415955D8&simid=608044552710852595',
#         'webSearchUrlPingSuffix': 'DevEx,5400.1',
#         'width': 304},
#        {'accentColor': '586973',
#         'contentSize': '105151 B',
#         'contentUrl': 'https://s-media-cache-ak0.pinimg.com/736x/eb/90/51/eb9051e0283eed2e583510896ef1e44d.jpg',
#         'contentUrlPingSuffix': 'DevEx,5408.1',
#         'datePublished': '2017-05-05T21:46:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 1024,
#         'hostPageDisplayUrl': 'https://www.pinterest.com/explore/madrid-street-style',
#         'hostPageUrl': 'https://www.pinterest.com/explore/madrid-street-style/',
#         'hostPageUrlPingSuffix': 'DevEx,5407.1',
#         'imageId': '48E70276DB85EEA33D3635305036CD27C3233A8B',
#         'imageInsightsToken': 'ccid_O3+KHdMj*mid_48E70276DB85EEA33D3635305036CD27C3233A8B*simid_608024877491817069*thid_OIP.O3-KHdMjFYf0zUjjEKlUEQHaLG',
#         'insightsMetadata': {'availableSizesCount': 2,
#          'pagesIncludingCount': 10},
#         'name': '17 Best ideas about Madrid Street Style on Pinterest ...',
#         'thumbnail': {'height': 710, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.O3-KHdMjFYf0zUjjEKlUEQHaLG&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=48E70276DB85EEA33D3635305036CD27C3233A8B&simid=608024877491817069',
#         'webSearchUrlPingSuffix': 'DevEx,5406.1',
#         'width': 683},
#        {'accentColor': '4E5B38',
#         'contentSize': '80656 B',
#         'contentUrl': 'http://1.bp.blogspot.com/-S4BTpAv1KVI/UC_7AUJW9aI/AAAAAAAAIuE/13WNQ0mHdi0/s1600/p%C3%BCsk%C3%BCll%C3%BC+etek+6.jpg',
#         'contentUrlPingSuffix': 'DevEx,5414.1',
#         'datePublished': '2018-07-09T22:41:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 652,
#         'hostPageDisplayUrl': 'www.gardropkedisi.com/2012/08/puskullu-etekler.html',
#         'hostPageUrl': 'http://www.gardropkedisi.com/2012/08/puskullu-etekler.html',
#         'hostPageUrlPingSuffix': 'DevEx,5413.1',
#         'imageId': 'D44DA23F4EB1C77089C5D139F595B7CE407C29F9',
#         'imageInsightsToken': 'ccid_bH7iLdqm*mid_D44DA23F4EB1C77089C5D139F595B7CE407C29F9*simid_608002582293581520*thid_OIP.bH7iLdqmlYplYnCgqgT82QHaJq',
#         'insightsMetadata': {'availableSizesCount': 2,
#          'pagesIncludingCount': 4},
#         'name': 'Gardrop Kedisi: Püsküllü etekler',
#         'thumbnail': {'height': 618, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP.bH7iLdqmlYplYnCgqgT82QHaJq&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=D44DA23F4EB1C77089C5D139F595B7CE407C29F9&simid=608002582293581520',
#         'webSearchUrlPingSuffix': 'DevEx,5412.1',
#         'width': 500},
#        {'accentColor': 'BD0E85',
#         'contentSize': '59508 B',
#         'contentUrl': 'http://stilnaja.ru/wp-content/uploads/2011/05/pljazhnaja-moda-2018-tendencii2-700x484.jpg',
#         'contentUrlPingSuffix': 'DevEx,5420.1',
#         'datePublished': '2017-12-19T13:31:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 484,
#         'hostPageDisplayUrl': 'stilnaja.ru/pljazhnaja-moda-2018-tendencii',
#         'hostPageUrl': 'http://stilnaja.ru/pljazhnaja-moda-2018-tendencii/',
#         'hostPageUrlPingSuffix': 'DevEx,5419.1',
#         'imageId': '2CDFEB23EE2083F9B18170714B13E3309017E149',
#         'imageInsightsToken': 'ccid_rDJ85o3X*mid_2CDFEB23EE2083F9B18170714B13E3309017E149*simid_608038535481658335*thid_OIP.rDJ85o3XaL!_n0VUoCm4AxAHaFH',
#         'insightsMetadata': {'availableSizesCount': 9,
#          'pagesIncludingCount': 12},
#         'name': 'Пляжная мода 2018 для девушек и полных женщин: модные ...',
#         'thumbnail': {'height': 327, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.rDJ85o3XaL_n0VUoCm4AxAHaFH&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=2CDFEB23EE2083F9B18170714B13E3309017E149&simid=608038535481658335',
#         'webSearchUrlPingSuffix': 'DevEx,5418.1',
#         'width': 700},
#        {'accentColor': 'A0412B',
#         'contentSize': '224329 B',
#         'contentUrl': 'http://static1.squarespace.com/static/511b12efe4b0d075328d3e82/563cdcc3e4b00d0a3b367d47/563cdcc5e4b07255a464274d/1446829377688/22679858446_c014789a9a_h.jpg',
#         'contentUrlPingSuffix': 'DevEx,5426.1',
#         'datePublished': '2015-11-06T12:00:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 2072,
#         'hostPageDisplayUrl': 'blog.styleestate.com/fashion-estate/2015/11/6/fashion-trends-daily...',
#         'hostPageUrl': 'http://blog.styleestate.com/fashion-estate/2015/11/6/fashion-trends-daily-25-stylish-new-outfits-on-the-street-fw-2016',
#         'hostPageUrlPingSuffix': 'DevEx,5425.1',
#         'imageId': 'DFE34F715A7C89872B2AE8743FF79E8F249045DA',
#         'imageInsightsToken': 'ccid_/CEPGsJw*mid_DFE34F715A7C89872B2AE8743FF79E8F249045DA*simid_608006937396645562*thid_OIP.!_CEPGsJwDuuDCV7IKIB49QHaPW',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 1},
#         'name': 'Fashion Trends Daily - 25 Stylish New Outfits On The ...',
#         'thumbnail': {'height': 982, 'width': 474},
#         'thumbnailUrl': 'https://tse2.mm.bing.net/th?id=OIP._CEPGsJwDuuDCV7IKIB49QHaPW&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=DFE34F715A7C89872B2AE8743FF79E8F249045DA&simid=608006937396645562',
#         'webSearchUrlPingSuffix': 'DevEx,5424.1',
#         'width': 1000},
#        {'accentColor': '0E2387',
#         'contentSize': '229895 B',
#         'contentUrl': 'https://c2.staticflickr.com/8/7393/13867157784_7283a0bf53_b.jpg',
#         'contentUrlPingSuffix': 'DevEx,5432.1',
#         'datePublished': '2016-04-04T11:03:00.0000000Z',
#         'encodingFormat': 'jpeg',
#         'height': 683,
#         'hostPageDisplayUrl': 'https://www.flickr.com/photos/93772654@N07/13867157784',
#         'hostPageUrl': 'https://www.flickr.com/photos/93772654@N07/13867157784',
#         'hostPageUrlPingSuffix': 'DevEx,5431.1',
#         'imageId': '7F0D2BA289F14407FF4C018E7354FF98237D7A4B',
#         'imageInsightsToken': 'ccid_Wvb1D6uy*mid_7F0D2BA289F14407FF4C018E7354FF98237D7A4B*simid_608049444721528283*thid_OIP.Wvb1D6uyzvLjCdTnGYdiYAHaE8',
#         'insightsMetadata': {'availableSizesCount': 1,
#          'pagesIncludingCount': 2},
#         'name': 'spf1_1 | Jessie Chanes Herrera | Flickr',
#         'thumbnail': {'height': 316, 'width': 474},
#         'thumbnailUrl': 'https://tse1.mm.bing.net/th?id=OIP.Wvb1D6uyzvLjCdTnGYdiYAHaE8&pid=Api',
#         'webSearchUrl': 'https://www.bing.com/images/search?view=detailv2&FORM=OIIRPO&id=7F0D2BA289F14407FF4C018E7354FF98237D7A4B&simid=608049444721528283',
#         'webSearchUrlPingSuffix': 'DevEx,5430.1',
#         'width': 1024}]}},
#     {'actionType': 'ImageById'}],
#    'displayName': ''},
#   {'actions': [{'actionType': 'ImageResults',
#      'displayName': 'jeans',
#      'serviceUrl': 'https://api.cognitive.microsoft.com/api/v7/images/search?q=jeans',
#      'webSearchUrl': 'https://www.bing.com/images/search?q=jeans',
#      'webSearchUrlPingSuffix': 'DevEx,5435.1'}],
#    'boundingBox': {'displayRectangle': {'bottomLeft': {'x': 0, 'y': 1},
#      'bottomRight': {'x': 1, 'y': 1},
#      'topLeft': {'x': 0, 'y': 0},
#      'topRight': {'x': 1, 'y': 0}},
#     'queryRectangle': {'bottomLeft': {'x': 0, 'y': 1},
#      'bottomRight': {'x': 1, 'y': 1},
#      'topLeft': {'x': 0, 'y': 0},
#      'topRight': {'x': 1, 'y': 0}}},
#    'displayName': 'jeans',
#    'image': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=jeans&pid=Api&mkt=pt-BR&adlt=moderate'}},
#   {'actions': [{'_type': 'ImageModuleAction', 'actionType': 'VisualSearch'},
#     {'_type': 'ImageModuleAction', 'actionType': 'ProductVisualSearch'}],
#    'boundingBox': {'displayRectangle': {'bottomLeft': {'x': 0.5749777,
#       'y': 0.652618},
#      'bottomRight': {'x': 0.5749777, 'y': 0.652618},
#      'topLeft': {'x': 0.5749777, 'y': 0.652618},
#      'topRight': {'x': 0.5749777, 'y': 0.652618}},
#     'queryRectangle': {'bottomLeft': {'x': 0.3995982, 'y': 0.8533908},
#      'bottomRight': {'x': 0.6802054, 'y': 0.8533908},
#      'topLeft': {'x': 0.3995982, 'y': 0.4518452},
#      'topRight': {'x': 0.6802054, 'y': 0.4518452}}},
#    'displayName': 'Pants',
#    'image': {'thumbnailUrl': 'https://tse1.mm.bing.net/th?q=Pants&pid=Api&mkt=pt-BR&adlt=moderate'}},
#   {'actions': [{'_type': 'ImageModuleAction', 'actionType': 'VisualSearch'},
#     {'_type': 'ImageModuleAction', 'actionType': 'ProductVisualSearch'}],
#    'boundingBox': {'displayRectangle': {'bottomLeft': {'x': 0.5733144,
#       'y': 0.4551851},
#      'bottomRight': {'x': 0.5733144, 'y': 0.4551851},
#      'topLeft': {'x': 0.5733144, 'y': 0.4551851},
#      'topRight': {'x': 0.5733144, 'y': 0.4551851}},
#     'queryRectangle': {'bottomLeft': {'x': 0.3466382, 'y': 0.6762096},
#      'bottomRight': {'x': 0.7093202, 'y': 0.6762096},
#      'topLeft': {'x': 0.3466382, 'y': 0.2341607},
#      'topRight': {'x': 0.7093202, 'y': 0.2341607}}},
#    'displayName': 'Coat',
#    'image': {'thumbnailUrl': 'https://tse4.mm.bing.net/th?q=Coat&pid=Api&mkt=pt-BR&adlt=moderate'}},
#   {'actions': [{'_type': 'ImageModuleAction', 'actionType': 'VisualSearch'},
#     {'_type': 'ImageModuleAction', 'actionType': 'ProductVisualSearch'}],
#    'boundingBox': {'displayRectangle': {'bottomLeft': {'x': 0.4293687,
#       'y': 0.9181736},
#      'bottomRight': {'x': 0.4293687, 'y': 0.9181736},
#      'topLeft': {'x': 0.4293687, 'y': 0.9181736},
#      'topRight': {'x': 0.4293687, 'y': 0.9181736}},
#     'queryRectangle': {'bottomLeft': {'x': 0.3656048, 'y': 0.9722245},
#      'bottomRight': {'x': 0.4676271, 'y': 0.9722245},
#      'topLeft': {'x': 0.3656048, 'y': 0.8641226},
#      'topRight': {'x': 0.4676271, 'y': 0.8641226}}},
#    'displayName': 'Heels',
#    'image': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Heels&pid=Api&mkt=pt-BR&adlt=moderate'}},
#   {'actions': [{'_type': 'ImageModuleAction', 'actionType': 'VisualSearch'},
#     {'_type': 'ImageModuleAction', 'actionType': 'ProductVisualSearch'}],
#    'boundingBox': {'displayRectangle': {'bottomLeft': {'x': 0.6038236,
#       'y': 0.9305016},
#      'bottomRight': {'x': 0.6038236, 'y': 0.9305016},
#      'topLeft': {'x': 0.6038236, 'y': 0.9305016},
#      'topRight': {'x': 0.6038236, 'y': 0.9305016}},
#     'queryRectangle': {'bottomLeft': {'x': 0.5262697, 'y': 0.9824879},
#      'bottomRight': {'x': 0.6503559, 'y': 0.9824879},
#      'topLeft': {'x': 0.5262697, 'y': 0.8785153},
#      'topRight': {'x': 0.6503559, 'y': 0.8785153}}},
#    'displayName': 'Heels',
#    'image': {'thumbnailUrl': 'https://tse2.mm.bing.net/th?q=Heels&pid=Api&mkt=pt-BR&adlt=moderate'}},
#   {'actions': [{'actionType': 'TextResults', 'displayName': 'IS LICIT CON'},
#     {'_type': 'ImageKnowledge/TextRecognitionAction',
#      'actionType': 'TextRecognition',
#      'data': {'regions': [{'boundingBox': {'bottomLeft': {'x': 0.4245902,
#           'y': 0.3752834},
#          'bottomRight': {'x': 0.5803279, 'y': 0.3752834},
#          'topLeft': {'x': 0.4245902, 'y': 0.3390023},
#          'topRight': {'x': 0.5803279, 'y': 0.3390023}},
#         'lines': [{'boundingBox': {'bottomLeft': {'x': 0.442623,
#             'y': 0.3390023},
#            'bottomRight': {'x': 0.552459, 'y': 0.3401361},
#            'topLeft': {'x': 0.442623, 'y': 0.2913832},
#            'topRight': {'x': 0.5491803, 'y': 0.292517}},
#           'text': 'IS',
#           'words': [{'boundingBox': {'bottomLeft': {'x': 0.4655738,
#               'y': 0.3390023},
#              'bottomRight': {'x': 0.5426229, 'y': 0.3401361},
#              'topLeft': {'x': 0.4655738, 'y': 0.2913832},
#              'topRight': {'x': 0.5442623, 'y': 0.292517}},
#             'text': 'IS'}]},
#          {'boundingBox': {'bottomLeft': {'x': 0.4245902, 'y': 0.3718821},
#            'bottomRight': {'x': 0.5786885, 'y': 0.3752834},
#            'topLeft': {'x': 0.4262295, 'y': 0.3390023},
#            'topRight': {'x': 0.5803279, 'y': 0.3412699}},
#           'text': 'LICIT CON',
#           'words': [{'boundingBox': {'bottomLeft': {'x': 0.4229508,
#               'y': 0.3741497},
#              'bottomRight': {'x': 0.5098361, 'y': 0.3752834},
#              'topLeft': {'x': 0.4245902, 'y': 0.3401361},
#              'topRight': {'x': 0.5081967, 'y': 0.3435374}},
#             'text': 'LICIT'},
#            {'boundingBox': {'bottomLeft': {'x': 0.5065574, 'y': 0.3752834},
#              'bottomRight': {'x': 0.5754098, 'y': 0.3752834},
#              'topLeft': {'x': 0.504918, 'y': 0.3435374},
#              'topRight': {'x': 0.5721312, 'y': 0.3435374}},
#             'text': 'CON'}]}]}]}}],
#    'boundingBox': {'displayRectangle': {'bottomLeft': {'x': 0, 'y': 1},
#      'bottomRight': {'x': 1, 'y': 1},
#      'topLeft': {'x': 0, 'y': 0},
#      'topRight': {'x': 1, 'y': 0}},
#     'queryRectangle': {'bottomLeft': {'x': 0, 'y': 1},
#      'bottomRight': {'x': 1, 'y': 1},
#      'topLeft': {'x': 0, 'y': 0},
#      'topRight': {'x': 1, 'y': 0}}},
#    'displayName': '##TextRecognition',
#    'sources': ['OCR']}]}

# %%
#response.json().keys()

# %%
import cv2

# %%
def auxRectangles(top_left, bottom_right, shape):
    new_top_left = (int(shape[1]*top_left['x']),int(shape[0]*top_left['y']))
    new_bottom_right = (int(shape[1]*bottom_right['x']),int(shape[0]*bottom_right['y']))
    return(new_top_left, new_bottom_right)

# %%
for element in response.json()['tags']:
    print(element.keys())
    print(element['displayName'])
    try:
        print(element['boundingBox'])
        top_left, bottom_right = auxRectangles(element['boundingBox']['queryRectangle']['topLeft'],\
                                               element['boundingBox']['queryRectangle']['bottomRight'],\
                                               img.shape)
        
        cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)
    except:
        pass
    
    
    print("\n\n")
# Out:
# dict_keys(['displayName', 'actions'])
#
#
#
#
# dict_keys(['image', 'displayName', 'boundingBox', 'actions'])
# jeans
# {'queryRectangle': {'topLeft': {'x': 0, 'y': 0}, 'topRight': {'x': 1, 'y': 0}, 'bottomRight': {'x': 1, 'y': 1}, 'bottomLeft': {'x': 0, 'y': 1}}, 'displayRectangle': {'topLeft': {'x': 0, 'y': 0}, 'topRight': {'x': 1, 'y': 0}, 'bottomRight': {'x': 1, 'y': 1}, 'bottomLeft': {'x': 0, 'y': 1}}}
#
#
#
# dict_keys(['image', 'displayName', 'boundingBox', 'actions'])
# Pants
# {'queryRectangle': {'topLeft': {'x': 0.3995982, 'y': 0.4518452}, 'topRight': {'x': 0.6802054, 'y': 0.4518452}, 'bottomRight': {'x': 0.6802054, 'y': 0.8533908}, 'bottomLeft': {'x': 0.3995982, 'y': 0.8533908}}, 'displayRectangle': {'topLeft': {'x': 0.5749777, 'y': 0.652618}, 'topRight': {'x': 0.5749777, 'y': 0.652618}, 'bottomRight': {'x': 0.5749777, 'y': 0.652618}, 'bottomLeft': {'x': 0.5749777, 'y': 0.652618}}}
#
#
#
# dict_keys(['image', 'displayName', 'boundingBox', 'actions'])
# Coat
# {'queryRectangle': {'topLeft': {'x': 0.3466382, 'y': 0.2341607}, 'topRight': {'x': 0.7093202, 'y': 0.2341607}, 'bottomRight': {'x': 0.7093202, 'y': 0.6762096}, 'bottomLeft': {'x': 0.3466382, 'y': 0.6762096}}, 'displayRectangle': {'topLeft': {'x': 0.5733144, 'y': 0.4551851}, 'topRight': {'x': 0.5733144, 'y': 0.4551851}, 'bottomRight': {'x': 0.5733144, 'y': 0.4551851}, 'bottomLeft': {'x': 0.5733144, 'y': 0.4551851}}}
#
#
#
# dict_keys(['image', 'displayName', 'boundingBox', 'actions'])
# Heels
# {'queryRectangle': {'topLeft': {'x': 0.3656048, 'y': 0.8641226}, 'topRight': {'x': 0.4676271, 'y': 0.8641226}, 'bottomRight': {'x': 0.4676271, 'y': 0.9722245}, 'bottomLeft': {'x': 0.3656048, 'y': 0.9722245}}, 'displayRectangle': {'topLeft': {'x': 0.4293687, 'y': 0.9181736}, 'topRight': {'x': 0.4293687, 'y': 0.9181736}, 'bottomRight': {'x': 0.4293687, 'y': 0.9181736}, 'bottomLeft': {'x': 0.4293687, 'y': 0.9181736}}}
#
#
#
# dict_keys(['image', 'displayName', 'boundingBox', 'actions'])
# Heels
# {'queryRectangle': {'topLeft': {'x': 0.5262697, 'y': 0.8785153}, 'topRight': {'x': 0.6503559, 'y': 0.8785153}, 'bottomRight': {'x': 0.6503559, 'y': 0.9824879}, 'bottomLeft': {'x': 0.5262697, 'y': 0.9824879}}, 'displayRectangle': {'topLeft': {'x': 0.6038236, 'y': 0.9305016}, 'topRight': {'x': 0.6038236, 'y': 0.9305016}, 'bottomRight': {'x': 0.6038236, 'y': 0.9305016}, 'bottomLeft': {'x': 0.6038236, 'y': 0.9305016}}}
#
#
#
# dict_keys(['displayName', 'boundingBox', 'actions', 'sources'])
# ##TextRecognition
# {'queryRectangle': {'topLeft': {'x': 0, 'y': 0}, 'topRight': {'x': 1, 'y': 0}, 'bottomRight': {'x': 1, 'y': 1}, 'bottomLeft': {'x': 0, 'y': 1}}, 'displayRectangle': {'topLeft': {'x': 0, 'y': 0}, 'topRight': {'x': 1, 'y': 0}, 'bottomRight': {'x': 1, 'y': 1}, 'bottomLeft': {'x': 0, 'y': 1}}}

# %%
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off')
plt.show()
